# %%
#!pip install ../input/pythongdcm/python_gdcm-3.0.9.0-cp37-cp37m-manylinux2014_x86_64.whl

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#import gdcm
from tqdm import tqdm
import cv2
#import pydicom
import imageio
#from pydicom.pixel_data_handlers.util import apply_voi_lut
from skimage.transform import resize
import warnings
warnings.filterwarnings('ignore')
import os
from PIL import Image
import imageio
import matplotlib.image as mpimg
import glob
import tensorflow as tf
import torch
import shutil

# %%
os.makedirs('./dataset')
os.makedirs('./yolov5')

# %%
def copytree(src, dst, symlinks=False, ignore=None):
    for item in os.listdir(src):
        s = os.path.join(src, item)
        d = os.path.join(dst, item)
        if os.path.isdir(s):
            shutil.copytree(s, d, symlinks, ignore)
        else:
            shutil.copy2(s, d)

# %%
copytree('../input/yolo-dataset-only-orig-640/dataset', './dataset')

# %%
copytree('../input/yolov5-dataset-and-yolo-608/yolov5/yolov5', './yolov5')

# %%
shutil.copy('../input/yolov5x-epoch-31-weights/yolov5x_epoch_31.pt', './yolov5/')

# %%
os.listdir('./yolov5')

# %%
# %cd yolov5

# %%
# %pip install -qr requirements.txt

# %%
# !pwd

# %%
IMG_SIZE = 640
Epochs = 50

# %%
# Install W&B 
# !pip install -q --upgrade wandb
# Login 
import wandb
wandb.login()

# %%
#!python train.py --img 640 --batch 16 --epochs 50 --data SIIM_data.yaml --cfg yolov5x.yaml --weights yolov5x_3rd_epoch.pt --save_period 1 --cache --project kaggle-siim-v5x-640-orig

# %%
#python train.py --resume runs/exp17/weights/last.pt

# %%
#!python train.py --img 640 --batch 16 --epochs 50 --data SIIM_data.yaml --cfg yolov5x.yaml --weights yolov5x_15th_epoch.pt --save_period 1 --cache --project kaggle-siim-v5x-640-orig

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data SIIM_data.yaml --cfg yolov5x.yaml --weights yolov5x_epoch_31.pt --save_period 1 --cache --project kaggle-siim-v5x-640-orig
